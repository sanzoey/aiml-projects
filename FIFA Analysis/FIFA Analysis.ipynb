# %%
# import necessary packages

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# read the data

fifa_df = pd.read_csv('fifa.csv')
fifa_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
# check the columns

fifa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
# checking footballers based on nationality

def country(x):
    return fifa_df[fifa_df['Nationality'] == x][['Position', 'Name', 'Overall']]

# checking for german players
country('Germany')
# Out:
#       Position           Name  Overall
# 11         LCM       T. Kroos       90
# 18          GK  M. ter Stegen       89
# 22          GK       M. Neuer       89
# 34         LCB     M. Hummels       88
# 55          LW        L. Sané       86
# ...        ...            ...      ...
# 18101       GK      J. Hipper       50
# 18127       GK     N. Stephan       49
# 18145       GK     M. Harsman       49
# 18187       RB      C. Ehlich       47
# 18189       ST     A. Kaltner       47
#
# [1198 rows x 3 columns]

# %%
# checking footballers based on Club

def club(x):
    return fifa_df[fifa_df['Club'] == x][['Position', 'Name', 'Overall']]

club('Chelsea')
# Out:
#       Position                 Name  Overall
# 5           LF            E. Hazard       91
# 14         LDM             N. Kanté       89
# 69          RB          Azpilicueta       86
# 121         CM             Jorginho       84
# 140         RW              Willian       84
# 176        LCM           M. Kovačić       83
# 177         GK                 Kepa       83
# 200         LB        Marcos Alonso       83
# 209        LCB           David Luiz       83
# 219         CM        Cesc Fàbregas       83
# 257         CB           A. Rüdiger       82
# 265         ST               Morata       82
# 283         RW                Pedro       82
# 304         ST            O. Giroud       82
# 336        LCB       A. Christensen       81
# 534         CB            G. Cahill       80
# 590         RB        D. Zappacosta       79
# 641         CM        M. van Ginkel       79
# 646        CAM           R. Barkley       79
# 681         CM        D. Drinkwater       79
# ...

# %%
# checking the describe of the data

fifa_df.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
# checking the shape of the data

fifa_df.shape
# Out:
# (18207, 89)

# %%
# checking for columns with missing values

fifa_df.isna().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %%
fifa_df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag',
#        'Overall', 'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Special',
#        'Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until',
#        'Height', 'Weight', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW',
#        'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM',
#        'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Crossing',
#        'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling',
#        'Curve', 'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
# ...

# %%
# fill the missing values for the data

fifa_df['ShortPassing'].fillna(fifa_df['ShortPassing'].mean(), inplace = True)
fifa_df['Volleys'].fillna(fifa_df['Volleys'].mean(), inplace = True)
fifa_df['Dribbling'].fillna(fifa_df['Dribbling'].mean(), inplace = True)
fifa_df['Curve'].fillna(fifa_df['Curve'].mean(), inplace = True)
fifa_df['FKAccuracy'].fillna(fifa_df['FKAccuracy'], inplace = True)
fifa_df['LongPassing'].fillna(fifa_df['LongPassing'].mean(), inplace = True)
fifa_df['BallControl'].fillna(fifa_df['BallControl'].mean(), inplace = True)
fifa_df['HeadingAccuracy'].fillna(fifa_df['HeadingAccuracy'].mean(), inplace = True)
fifa_df['Finishing'].fillna(fifa_df['Finishing'].mean(), inplace = True)
fifa_df['Crossing'].fillna(fifa_df['Crossing'].mean(), inplace = True)
fifa_df['Weight'].fillna('200lbs', inplace = True)
fifa_df['Contract Valid Until'].fillna(2019, inplace = True)
fifa_df['Height'].fillna("5'11", inplace = True)
fifa_df['Loaned From'].fillna('None', inplace = True)
fifa_df['Joined'].fillna('Jul 1, 2018', inplace = True)
fifa_df['Jersey Number'].fillna(8, inplace = True)
fifa_df['Body Type'].fillna('Normal', inplace = True)
fifa_df['Position'].fillna('ST', inplace = True)
fifa_df['Club'].fillna('No Club', inplace = True)
fifa_df['Work Rate'].fillna('Medium/ Medium', inplace = True)
fifa_df['Skill Moves'].fillna(fifa_df['Skill Moves'].median(), inplace = True)
fifa_df['Weak Foot'].fillna(3, inplace = True)
fifa_df['Preferred Foot'].fillna('Right', inplace = True)
fifa_df['International Reputation'].fillna(1, inplace = True)
fifa_df['Wage'].fillna('€200K', inplace = True)
fifa_df.fillna(0, inplace = True)

# %%
# checking for columns with missing values

fifa_df.isna().sum()
# Out:
# Unnamed: 0        0
# ID                0
# Name              0
# Age               0
# Photo             0
#                  ..
# GKHandling        0
# GKKicking         0
# GKPositioning     0
# GKReflexes        0
# Release Clause    0
# Length: 89, dtype: int64

# %%
# Adding new columns

def defending(fifa_df):
    return int(round((fifa_df[['Marking', 'StandingTackle', 
                            'SlidingTackle']].mean()).mean()))

def general(data):
    return int(round((data[['HeadingAccuracy', 'Dribbling', 'Curve', 
                            'BallControl']].mean()).mean()))

def mental(data):
    return int(round((data[['Aggression', 'Interceptions', 'Positioning', 
                            'Vision','Composure']].mean()).mean()))

def passing(data):
    return int(round((data[['Crossing', 'ShortPassing', 
                            'LongPassing']].mean()).mean()))

def mobility(data):
    return int(round((data[['Acceleration', 'SprintSpeed', 
                            'Agility','Reactions']].mean()).mean()))
def power(data):
    return int(round((data[['Balance', 'Jumping', 'Stamina', 
                            'Strength']].mean()).mean()))

def rating(data):
    return int(round((data[['Potential', 
                            'Overall']].mean()).mean()))

def shooting(data):
    return int(round((data[['Finishing', 'Volleys', 'FKAccuracy','ShotPower',
                            'LongShots', 'Penalties']].mean()).mean()))

# %%
# renaming the column

fifa_df.rename(columns={'Club Logo':'Club_Logo'}, inplace=True)

# %%
# adding the additional columns to the data

fifa_df['Defending'] = fifa_df.apply(defending, axis = 1)
fifa_df['General'] = fifa_df.apply(general, axis = 1)
fifa_df['Mental'] = fifa_df.apply(mental, axis = 1)
fifa_df['Passing'] = fifa_df.apply(passing, axis = 1)
fifa_df['Mobility'] = fifa_df.apply(mobility, axis = 1)
fifa_df['Power'] = fifa_df.apply(power, axis = 1)
fifa_df['Rating'] = fifa_df.apply(rating, axis = 1)
fifa_df['Shooting'] = fifa_df.apply(shooting, axis = 1)

# %%
fifa_df.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# ## Data Visualization

# %%
# comparison of preferred foot of different players

plt.rcParams['figure.figsize'] = (6, 5)
sns.countplot(fifa_df['Preferred Foot'], palette = 'Greens_r')
plt.title('Most Preffered Foot of the Players', fontsize = 14)
plt.show()

# %%
# plotting a pie chart to represent share of international reputation

labels = ['1', '2', '3', '4', '5']
sizes = fifa_df['International Reputation'].value_counts()
colors = plt.cm.Dark2(np.linspace(0, 1, 5))
explode = [0.05, 0.1, 0.15, 0.2, 0.25]

plt.rcParams['figure.figsize'] = (8, 8)
plt.pie(sizes, labels = labels, colors = colors, explode = explode)
plt.title('International Reputation for the Football Players', fontsize = 14)
plt.legend()
plt.show()

# %%
# different positions acquired by the players

plt.rcParams['figure.figsize'] = (16, 10)
plt.style.use('fivethirtyeight')
ax = sns.countplot('Position', data = fifa_df, palette='Dark2')
ax.set_xlabel(xlabel = 'Different Positions in Football', fontsize = 14)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 14)
ax.set_title(label = 'Comparison of Position and Players', fontsize = 16)
plt.show()

# %%
# defining a function for cleaning the weight value

def extract_weight(value):
    out = value.replace('lbs', '')
    return float(out)

# applying the function to the weight column
fifa_df['Weight'] = fifa_df['Weight'].apply(lambda x: extract_weight(x))

# %%
fifa_df['Weight'].head()
# Out:
# 0    159.0
# 1    183.0
# 2    150.0
# 3    168.0
# 4    154.0
# Name: Weight, dtype: float64

# %%
# defining a function for cleaning the wage

def extract_wage(value):
    out = value.replace('€', '')
    if 'M' in out:
        out = float(out.replace('M', '')) * 1000000
    elif 'K' in out:
        out = float(out.replace('K', '')) * 1000
    return float(out)

# applying the function to the wage column
fifa_df['Wage'] = fifa_df['Wage'].apply(lambda x: extract_wage(x))

# %%
fifa_df['Wage'].head()
# Out:
# 0    565000.0
# 1    405000.0
# 2    290000.0
# 3    260000.0
# 4    355000.0
# Name: Wage, dtype: float64

# %%
# comparing the player wages

plt.rcParams['figure.figsize'] = (16, 8)
sns.distplot(fifa_df['Wage'], color='green')
plt.xlabel('Wage Range for Players', fontsize = 14)
plt.ylabel('Count of Player', fontsize = 14)
plt.title('Distribution of Wages of Players', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.figure(figsize = (8, 8))
ax = sns.countplot(x = 'Skill Moves', data = fifa_df, palette='Dark2')
ax.set_title(label = 'Count of Players on the Basis of their Skill Moves', fontsize = 20)
ax.set_xlabel(xlabel = 'Number of Skill Moves', fontsize = 14)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 14)
plt.show()

# %%
# height of players

plt.rcParams['figure.figsize'] = (16, 15)
ax = sns.countplot(x = 'Height', data = fifa_df, palette = 'Dark2')
ax.set_title(label = 'Count of Players on the Basis of their Height')
ax.set_xlabel(xlabel = 'Height in foot per inch', fontsize = 14)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 14)
plt.show()

# %%
# weight of players

plt.figure(figsize = (16, 10))
sns.distplot(fifa_df['Weight'], color = 'blue')
plt.title('Weight Distribution of Players', fontsize = 16)
plt.xlabel('Weight of Players', fontsize = 14)
plt.ylabel('Count of Players', fontsize = 14)
plt.show()

# %%
# work rate of players

plt.figure(figsize = (20, 8))
sns.countplot(x = 'Work Rate', data = fifa_df, palette = 'Dark2')
plt.title('Work Rate of Players', fontsize = 16)
plt.xlabel('Work Rate of Players', fontsize = 14)
plt.ylabel('Count of Players', fontsize = 14)
plt.show()

# %%
# speciality score of the players

plt.figure(figsize = (12, 8))
ax = sns.distplot(fifa_df['Special'], bins = 60, color = 'r')
ax.set_xlabel(xlabel = 'Speciality score range', fontsize = 14)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 14)
ax.set_title(label = 'Speciality Score for Players', fontsize = 16)
plt.show()

# %%
# potential scores for players

ax = sns.distplot(fifa_df['Potential'], bins = 30, color = 'g')
ax.set_xlabel(xlabel = 'Players Potential Scores', fontsize = 14)
ax.set_ylabel(ylabel = 'Count of Players', fontsize = 14)
ax.set_title(label = 'Potential of Players', fontsize = 16)
plt.show()

# %%
# to show different nations participation in fifa

plt.figure(figsize = (16, 8))
fifa_df['Nationality'].value_counts().head(30).plot.bar()
plt.title('Top 30 Participating Nations in FIFA', fontsize = 16)
plt.xlabel('Name of the Country', fontsize = 14)
plt.ylabel('No of Players', fontsize = 14)
plt.show()

# %%
# Top 10 countries with most players

fifa_df['Nationality'].value_counts().head(10)
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %%
# Some nations Player and their weight distribution

top_six = ['England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil']
top_six_df = fifa_df.loc[fifa_df['Nationality'].isin(top_six) & fifa_df['Weight']]
plt.rcParams['figure.figsize'] = (16, 8)
ax = sns.violinplot(x = top_six_df['Nationality'], y = top_six_df['Weight'])
ax.set_title(label = 'Country Wise Distibution of Weight', fontsize = 16)
ax.set_xlabel(xlabel = 'Countries', fontsize = 14)
ax.set_ylabel(ylabel = 'Weight in lbs', fontsize = 14)
plt.show()

# %%
fifa_df['Club'].value_counts().head(15)
# Out:
# No Club                    241
# TSG 1899 Hoffenheim         33
# Borussia Dortmund           33
# Real Madrid                 33
# Everton                     33
# Cardiff City                33
# Tottenham Hotspur           33
# Arsenal                     33
# Chelsea                     33
# Newcastle United            33
# Atlético Madrid             33
# Wolverhampton Wanderers     33
# CD Leganés                  33
# RC Celta                    33
# Manchester United           33
# Name: Club, dtype: int64

# %%
# analysing overall score distribution in clubs

some_clubs = ['Manchester United', 'RC Celta', 'Wolverhampton Wanderers'
              'Everton', 'Real Madrid', 'Cardiff City', 'Arsenal',
              'Tottenham Hotspur', 'Chelsea', 'Atlético Madrid']
overall_df = fifa_df.loc[fifa_df['Club'].isin(some_clubs) & fifa_df['Overall']]
plt.rcParams['figure.figsize'] = (16, 10)
ax = sns.boxplot(x = overall_df['Club'], y = overall_df['Overall'], palette = 'inferno')
ax.set_xlabel(xlabel = 'Club', fontsize = 14)
ax.set_ylabel(ylabel = 'Overall Score', fontsize = 14)
ax.set_title(label = 'Overall Score Distribution', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %%
# distribution of wages in clubs

wage_df = fifa_df.loc[fifa_df['Club'].isin(some_clubs) & fifa_df['Wage']]
ax = sns.boxplot(x = wage_df['Club'], y = wage_df['Wage'], palette = 'Dark2')
ax.set_xlabel(xlabel = 'Club', fontsize = 14)
ax.set_ylabel(ylabel = 'Distribution of Wage', fontsize = 14)
ax.set_title(label = 'Club Wage Distribution', fontsize = 16)
plt.xticks(rotation = 90)
plt.show()

# %%
# comparing performance of left footed and right footed players

# ball control vs dribbling
sns.lmplot(x = 'BallControl', y = 'Dribbling', 
           col = 'Preferred Foot', data = fifa_df)
plt.show()
